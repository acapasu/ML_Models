# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
a = sns.load_dataset('tips')
print(a.shape)
a.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pen = sns.load_dataset('penguins')
pen.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.violinplot(data=pen,x='sex',y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(data=pen,y='body_mass_g',x='island',hue='sex')
plt.legend(loc=(1.1,0.5))

# %%
plt.figure(figsize=(10,3),dpi=200)
sns.displot(data=pen,x='bill_length_mm',bins=70,col='island',row='sex');

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.catplot(data=pen,x='island',hue='sex',col='species',kind='count')

# %%
cars = sns.load_dataset('car_crashes')

# %%
cars.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.distplot(cars['total'], bins= 20 ,hist = True, kde = False, rug = True)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total'>

# %%
sns.jointplot(x = cars['speeding'], y = cars['total'])

# %%
sns.jointplot('speeding', 'total', cars, kind= "hex")
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pen = sns.load_dataset('penguins')

# %%
pen.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
pen['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
pen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# sns.set(font_scale=1.5)
sns.pairplot(pen)

# %%
sns.pairplot(pen, hue = 'sex', diag_kind='hist', kind = 'reg', palette = 'pastel')

# %%
g  = sns.PairGrid(pen)
g.map(plt.scatter)

# %%
g  = sns.PairGrid(pen)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g = sns.FacetGrid(pen,'sex' ,'island' )
g.map(plt.hist, 'body_mass_g')
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: row, col. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.FacetGrid(pen,'sex' ,'island', hue = 'species' )
g.map(plt.scatter, 'body_mass_g', 'flipper_length_mm').add_legend()
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: row, col. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g = sns.JointGrid('body_mass_g' ,'flipper_length_mm', pen)
g.plot(plt.scatter, sns.distplot)
# g.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
sns.lmplot('body_mass_g' ,'flipper_length_mm', pen, hue = 'sex', palette = 'pastel')
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x = 'island', y = 'body_mass_g', data = pen, hue = 'sex', estimator = np.std)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.countplot(x = 'island', data = pen, hue='sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
sns.set_style('white')
# sns.set_style("whitegrid")
# sns.set_style("dark")
# sns.set_style('ticks')
sns.countplot(x = 'island', data = pen, hue='sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
sns.countplot(x = 'island', data = pen, hue='sex')
sns.despine(left = True, bottom=True)

# %%
plt.figure(figsize=(14,4))
sns.countplot(x = 'island', data = pen, hue='sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
# sns.set_context('paper')
sns.set_context('notebook', font_scale=1)
# sns.set_context('talk')
# sns.set_context('poster')

sns.countplot(x = 'island', data = pen, hue='sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='count'>

# %%
sns.boxplot(x = 'island', y = 'body_mass_g', data = pen, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x = 'island', y = 'body_mass_g', data = pen, hue = 'sex', split = True)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.stripplot(x = 'island', y = 'body_mass_g', data = pen, size = 4, jitter = True, hue = 'sex', dodge = True)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.swarmplot(x = 'island', y = 'body_mass_g', data = pen, hue = 'sex', dodge = True)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
sns.boxplot(x = 'island', y = 'body_mass_g', data = pen)
sns.swarmplot(x = 'island', y = 'body_mass_g', data = pen, color = 'black')
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
pen.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data = pen.corr(), annot=True, cmap = "Spectral", linecolor='white', linewidths=5)
# Out:
# <AxesSubplot:>

# %%
sd = pd.DataFrame()
for i in os.listdir('C:\\Users\\andre\\Desktop\\Curso_Ciencia_de_Datos\\semana7//data//Sales_Data'):
    sd = sd.append(pd.read_csv('C:\\Users\\andre\\Desktop\\Curso_Ciencia_de_Datos\\semana7//data//Sales_Data//' + i))
sd = sd.dropna(subset = ['Order Date'])
sd = sd[['Product', 'Quantity Ordered', 'Order Date']]
sd = sd.sort_values('Order Date', ascending=False)
sd = sd.iloc[355:,:]
sd['mes']=sd['Order Date'].str[:2]
sd = sd.drop('Order Date', axis = 1)
sd['Quantity Ordered'] = sd['Quantity Ordered'].astype(int)
sd = sd.pivot_table(values='Quantity Ordered', index = 'Product', columns= 'mes' , aggfunc=sum)
sd.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-60e8c88ce46d> in <module>
#       1 sd = pd.DataFrame()
# ----> 2 for i in os.listdir('C:\\Users\\andre\\Desktop\\Curso_Ciencia_de_Datos\\semana7//data//Sales_Data'):
#       3     sd = sd.append(pd.read_csv('C:\\Users\\andre\\Desktop\\Curso_Ciencia_de_Datos\\semana7//data//Sales_Data//' + i))
#       4 sd = sd.dropna(subset = ['Order Date'])
#       5 sd = sd[['Product', 'Quantity Ordered', 'Order Date']]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\andre\\Desktop\\Curso_Ciencia_de_Datos\\semana7//data//Sales_Data'

# %%
sns.clustermap(sd, cmap='coolwarm', standard_scale=1)
