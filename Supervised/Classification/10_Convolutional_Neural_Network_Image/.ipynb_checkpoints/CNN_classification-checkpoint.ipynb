# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import datetime

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

import pickle

# %%
print(tf. __version__)
# Out:
# 2.6.2

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## TensorBoard

# %%
# log_directory = 'logs\\fit_' + datetime.datetime.now().strftime("%Y-%m-%d--%H-%M")
# board = TensorBoard(log_dir=log_directory,histogram_freq=1,
#     write_graph=True,
#     write_images=True,
#     update_freq='epoch',
#     profile_batch=2,
#     embeddings_freq=1)

# %%
# pwd

# %% [markdown]
# tensorboard --logdir logs\fit
#
# http://localhost:6006/#scalars

# %% [markdown]
# ## Import Dataset

# %% [markdown]
# dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

# %%
data_dir = 'C:\\Users\\andre\\Documents\\Datasets\\flower_photos'

# %%
image_count = 0
class_names = []
for i in os.scandir(data_dir):
    if i.is_dir():
        print(f'La carpeta {i.name} tiene {len(os.listdir(i))} imagenes')
        image_count += len(os.listdir(i))
        class_names.append(i.name)
        
print('------------')
print(f'El total de imagenes es {image_count}')
# Out:
# La carpeta daisy tiene 633 imagenes
# La carpeta dandelion tiene 898 imagenes
# La carpeta roses tiene 641 imagenes
# La carpeta sunflowers tiene 699 imagenes
# La carpeta tulips tiene 799 imagenes
# ------------
# El total de imagenes es 3670

# %%
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
daisy = os.listdir(data_dir+'/daisy')
daisy = [data_dir + '/daisy/' + flower for flower in daisy] 

dandelion = os.listdir(data_dir+'/dandelion')
dandelion = [data_dir + '/dandelion/' + flower for flower in dandelion] 

roses = os.listdir(data_dir+'/roses')
roses = [data_dir + '/roses/' + flower for flower in roses] 

sunflowers = os.listdir(data_dir+'/sunflowers')
sunflowers = [data_dir + '/sunflowers/' + flower for flower in sunflowers] 

tulips = os.listdir(data_dir+'/tulips')
tulips = [data_dir + '/tulips/' + flower for flower in tulips]

# %%
imread(roses[0]).shape
# Out:
# (240, 179, 3)

# %%
plt.imshow(imread(roses[0]))

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Finding the best shape

# %%
counter = 0
dim1 = []
dim2 = []
colors_temp = []
for i in os.scandir(data_dir):
    if i.is_dir():
        actual = os.listdir(data_dir+'/' + i.name)
        for j in actual:
            counter +=1
            img = imread(data_dir + '/' + i.name + '/' + j)
            d1,d2,colors = img.shape
            dim1.append(d1)
            dim2.append(d2)
            colors_temp.append(colors)

# %%
print(counter)
print(np.array(dim1).mean())
print(np.array(dim2).mean())
print(pd.Series(colors_temp).unique())
# Out:
# 3670
# 271.79128065395093
# 365.0623978201635
# [3]

# %%
sns.jointplot(x = dim1,y = dim2)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# # Explicit Dataset

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir+'/*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
    print(f.numpy())
# Out:
# b'C:\\Users\\andre\\Documents\\Datasets\\flower_photos\\tulips\\8454719295_4276c0e9c5_n.jpg'
# b'C:\\Users\\andre\\Documents\\Datasets\\flower_photos\\tulips\\5691672942_70a93d70fc.jpg'
# b'C:\\Users\\andre\\Documents\\Datasets\\flower_photos\\roses\\9300754115_dd79670066_n.jpg'
# b'C:\\Users\\andre\\Documents\\Datasets\\flower_photos\\roses\\5529341024_0c35f2657d.jpg'
# b'C:\\Users\\andre\\Documents\\Datasets\\flower_photos\\tulips\\3909355648_42cb3a5e09_n.jpg'

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 2936
# 734

# %%
def get_label(file_path):
    # Convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    # Integer encode the label
    return tf.argmax(one_hot)

# %%
def decode_img(img):
    # Convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # Resize the image to the desired size
    return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
    label = get_label(file_path)
    # Load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  1

# %%
def configure_for_performance(ds):
    ds = ds.cache()
    ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    plt.title(class_names[label])
    plt.axis("off")

# %%
num_classes = 5

# model = tf.keras.Sequential()
# model.add(tf.keras.layers.Rescaling(1./255))
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(num_classes))

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=200
)
# Out:
# Epoch 1/200
# 92/92 [==============================] - 18s 98ms/step - loss: 1.2689 - accuracy: 0.4527 - val_loss: 1.1269 - val_accuracy: 0.5654
# Epoch 2/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.9742 - accuracy: 0.6141 - val_loss: 0.9252 - val_accuracy: 0.6594
# Epoch 3/200
# 92/92 [==============================] - 6s 67ms/step - loss: 0.7794 - accuracy: 0.7057 - val_loss: 0.9719 - val_accuracy: 0.6308
# Epoch 4/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.6121 - accuracy: 0.7663 - val_loss: 0.8558 - val_accuracy: 0.6866
# Epoch 5/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.4539 - accuracy: 0.8345 - val_loss: 0.9690 - val_accuracy: 0.6608
# Epoch 6/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.2754 - accuracy: 0.9087 - val_loss: 1.1212 - val_accuracy: 0.6717
# Epoch 7/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.1799 - accuracy: 0.9428 - val_loss: 1.3191 - val_accuracy: 0.6540
# Epoch 8/200
# 92/92 [==============================] - 8s 88ms/step - loss: 0.1058 - accuracy: 0.9700 - val_loss: 1.5648 - val_accuracy: 0.6744
# Epoch 9/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0730 - accuracy: 0.9816 - val_loss: 1.8774 - val_accuracy: 0.6649
# Epoch 10/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0563 - accuracy: 0.9847 - val_loss: 2.0496 - val_accuracy: 0.6458
# Epoch 11/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0907 - accuracy: 0.9731 - val_loss: 1.7062 - val_accuracy: 0.6689
# Epoch 12/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0569 - accuracy: 0.9857 - val_loss: 1.9079 - val_accuracy: 0.6921
# Epoch 13/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0221 - accuracy: 0.9966 - val_loss: 1.9979 - val_accuracy: 0.6826
# Epoch 14/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0161 - accuracy: 0.9973 - val_loss: 2.2273 - val_accuracy: 0.6662
# Epoch 15/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 2.2696 - val_accuracy: 0.6866
# Epoch 16/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0058 - accuracy: 0.9993 - val_loss: 2.3701 - val_accuracy: 0.6785
# Epoch 17/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 2.4391 - val_accuracy: 0.6812
# Epoch 18/200
# 92/92 [==============================] - 8s 87ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 2.5209 - val_accuracy: 0.6839
# Epoch 19/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 2.4410 - val_accuracy: 0.6853
# Epoch 20/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 2.5082 - val_accuracy: 0.6839
# Epoch 21/200
# 92/92 [==============================] - 6s 66ms/step - loss: 6.5051e-04 - accuracy: 1.0000 - val_loss: 2.5679 - val_accuracy: 0.6880
# Epoch 22/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 2.4887 - val_accuracy: 0.6839
# Epoch 23/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 2.4360 - val_accuracy: 0.6826
# Epoch 24/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 2.4845 - val_accuracy: 0.6839
# Epoch 25/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 2.4328 - val_accuracy: 0.6853
# Epoch 26/200
# 92/92 [==============================] - 8s 88ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 2.4771 - val_accuracy: 0.6866
# Epoch 27/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.4690 - val_accuracy: 0.6866
# Epoch 28/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 2.5132 - val_accuracy: 0.6853
# Epoch 29/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 2.6008 - val_accuracy: 0.6826
# Epoch 30/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 2.5390 - val_accuracy: 0.6853
# Epoch 31/200
# 92/92 [==============================] - 6s 69ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 2.5342 - val_accuracy: 0.6826
# Epoch 32/200
# 92/92 [==============================] - 9s 94ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 2.5826 - val_accuracy: 0.6826
# Epoch 33/200
# 92/92 [==============================] - 6s 69ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 2.5211 - val_accuracy: 0.6866
# Epoch 34/200
# 92/92 [==============================] - 8s 90ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 2.5241 - val_accuracy: 0.6771
# Epoch 35/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 2.5767 - val_accuracy: 0.6730
# Epoch 36/200
# 92/92 [==============================] - 9s 97ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 2.6151 - val_accuracy: 0.6798
# Epoch 37/200
# 92/92 [==============================] - 6s 67ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 2.6237 - val_accuracy: 0.6812
# Epoch 38/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 2.5306 - val_accuracy: 0.6771
# Epoch 39/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 2.5313 - val_accuracy: 0.6744
# Epoch 40/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 2.5755 - val_accuracy: 0.6744
# Epoch 41/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 2.5815 - val_accuracy: 0.6771
# Epoch 42/200
# 92/92 [==============================] - 8s 86ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 2.5982 - val_accuracy: 0.6771
# Epoch 43/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 2.6702 - val_accuracy: 0.6717
# Epoch 44/200
# 92/92 [==============================] - 6s 65ms/step - loss: 8.9787e-04 - accuracy: 0.9997 - val_loss: 2.7108 - val_accuracy: 0.6703
# Epoch 45/200
# 92/92 [==============================] - 6s 65ms/step - loss: 9.7330e-04 - accuracy: 0.9997 - val_loss: 2.7109 - val_accuracy: 0.6798
# Epoch 46/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0011 - accuracy: 0.9993 - val_loss: 2.7895 - val_accuracy: 0.6676
# Epoch 47/200
# 92/92 [==============================] - 6s 65ms/step - loss: 9.2399e-04 - accuracy: 0.9993 - val_loss: 2.7228 - val_accuracy: 0.6839
# Epoch 48/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.3654 - accuracy: 0.8903 - val_loss: 1.4931 - val_accuracy: 0.6567
# Epoch 49/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.1957 - accuracy: 0.9312 - val_loss: 1.5617 - val_accuracy: 0.6635
# Epoch 50/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0753 - accuracy: 0.9755 - val_loss: 1.9762 - val_accuracy: 0.6512
# Epoch 51/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 2.1511 - val_accuracy: 0.6567
# Epoch 52/200
# 92/92 [==============================] - 8s 65ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 2.4520 - val_accuracy: 0.6771
# Epoch 53/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 2.5535 - val_accuracy: 0.6785
# Epoch 54/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.
# Epoch 155/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.0670e-04 - accuracy: 0.9993 - val_loss: 3.3298 - val_accuracy: 0.6499
# Epoch 156/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.6607e-04 - accuracy: 0.9993 - val_loss: 3.3277 - val_accuracy: 0.6499
# Epoch 157/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.2091 - val_accuracy: 0.6471
# Epoch 158/200
# 92/92 [==============================] - 6s 65ms/step - loss: 8.3896e-04 - accuracy: 0.9993 - val_loss: 3.2243 - val_accuracy: 0.6499
# Epoch 159/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.8375e-04 - accuracy: 0.9993 - val_loss: 3.2516 - val_accuracy: 0.6458
# Epoch 160/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.9910e-04 - accuracy: 0.9993 - val_loss: 3.2701 - val_accuracy: 0.6458
# Epoch 161/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.3368e-04 - accuracy: 0.9997 - val_loss: 3.2964 - val_accuracy: 0.6485
# Epoch 162/200
# 92/92 [==============================] - 8s 87ms/step - loss: 5.9678e-04 - accuracy: 0.9993 - val_loss: 3.4272 - val_accuracy: 0.6431
# Epoch 163/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0410 - accuracy: 0.9891 - val_loss: 2.5961 - val_accuracy: 0.6240
# Epoch 164/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.2286 - accuracy: 0.9309 - val_loss: 1.9057 - val_accuracy: 0.6226
# Epoch 165/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0728 - accuracy: 0.9813 - val_loss: 2.3473 - val_accuracy: 0.6417
# Epoch 166/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 2.7566 - val_accuracy: 0.6444
# Epoch 167/200
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 2.7936 - val_accuracy: 0.6403
# Epoch 168/200
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0011 - accuracy: 0.9993 - val_loss: 2.8629 - val_accuracy: 0.6431
# Epoch 169/200
# 92/92 [==============================] - 6s 66ms/step - loss: 9.0995e-04 - accuracy: 0.9993 - val_loss: 2.9160 - val_accuracy: 0.6417
# Epoch 170/200
# 92/92 [==============================] - 6s 65ms/step - loss: 8.0510e-04 - accuracy: 0.9993 - val_loss: 2.9585 - val_accuracy: 0.6417
# Epoch 171/200
# 92/92 [==============================] - 6s 65ms/step - loss: 7.2519e-04 - accuracy: 0.9993 - val_loss: 3.0018 - val_accuracy: 0.6471
# Epoch 172/200
# 92/92 [==============================] - 6s 65ms/step - loss: 6.4810e-04 - accuracy: 0.9993 - val_loss: 3.0360 - val_accuracy: 0.6458
# Epoch 173/200
# 92/92 [==============================] - 8s 69ms/step - loss: 6.5229e-04 - accuracy: 0.9993 - val_loss: 3.0674 - val_accuracy: 0.6458
# Epoch 174/200
# 92/92 [==============================] - 6s 66ms/step - loss: 5.5122e-04 - accuracy: 0.9997 - val_loss: 3.0882 - val_accuracy: 0.6458
# Epoch 175/200
# 92/92 [==============================] - 6s 66ms/step - loss: 6.2529e-04 - accuracy: 0.9993 - val_loss: 3.1030 - val_accuracy: 0.6471
# Epoch 194/200
# 92/92 [==============================] - 6s 65ms/step - loss: 5.1025e-04 - accuracy: 0.9993 - val_loss: 3.4184 - val_accuracy: 0.6471
# Epoch 195/200
# 92/92 [==============================] - 6s 65ms/step - loss: 5.0646e-04 - accuracy: 0.9993 - val_loss: 3.4295 - val_accuracy: 0.6471
# Epoch 196/200
# 92/92 [==============================] - 6s 65ms/step - loss: 5.0430e-04 - accuracy: 0.9997 - val_loss: 3.4394 - val_accuracy: 0.6458
# Epoch 197/200
# 92/92 [==============================] - 6s 65ms/step - loss: 4.9586e-04 - accuracy: 0.9997 - val_loss: 3.4526 - val_accuracy: 0.6444
# Epoch 198/200
# 92/92 [==============================] - 6s 65ms/step - loss: 4.8239e-04 - accuracy: 0.9997 - val_loss: 3.4656 - val_accuracy: 0.6444
# Epoch 199/200
# 92/92 [==============================] - 8s 65ms/step - loss: 5.0978e-04 - accuracy: 0.9993 - val_loss: 3.4772 - val_accuracy: 0.6458
# Epoch 200/200
# 92/92 [==============================] - 6s 65ms/step - loss: 5.0758e-04 - accuracy: 0.9993 - val_loss: 3.4901 - val_accuracy: 0.6485

# %% [markdown]
# ## Train/Test Split

# %%
## Cambiarlo al promedio
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
## Experimento para hacer lo mismo de arriba en un solo paso
# train_ds_e, val_ds_e = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   validation_split=0.2,
#   subset="both",
#   seed=123,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)

# %%
class_names = train_ds.class_names
print(class_names)

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break

# %% [markdown]
# ## Creating the Normalization Layer

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %% [markdown]
# ## Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Creating the Model

# %%
num_classes = 5

# model = tf.keras.Sequential()
# model.add(tf.keras.layers.Rescaling(1./255))
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
# model.add(tf.keras.layers.MaxPooling2D())
# model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(num_classes))

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=600, 
    use_multiprocessing = True
)

# %% [markdown]
# ## Evaluation

# %%
model.history.history

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
model.metrics_names

# %%
training_score = model.evaluate(X_train,y_train,verbose=0)
test_score = model.evaluate(X_test,y_test,verbose=0)

# %%
print(training_score)
print(test_score)

# %%
predictions = model.predict(X_test)

# %%
predictions.head()
