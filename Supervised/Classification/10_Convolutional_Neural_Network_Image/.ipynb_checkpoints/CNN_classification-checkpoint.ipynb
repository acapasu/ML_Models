# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

import pickle

# %%
print(tf. __version__)
# Out:
# 2.12.0

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## TensorBoard

# %%
log_directory = 'logs\\fit_' + datetime.datetime.now().strftime("%Y-%m-%d--%H-%M")
board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)

# %%
pwd
# Out:
# 'C:\\Users\\andre\\Documents\\Github_Repositories\\ML_Models\\Supervised\\Classification\\09_Artificial_Neural_Network'

# %% [markdown]
# tensorboard --logdir logs\fit
#
# http://localhost:6006/#scalars

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['species'], axis = 1)
y = df_pen['species']

# %% [markdown]
# ## Data Pre-processing

# %%
# categorical_x = ['species', 'island', 'sex']
# numerical_x = X.drop(categorical_x, axis = 1).columns

# %%
# ## If y is categorical:
# # y.fillna(y.mode(), inplace= True)
# ##If y is numerical
# y.fillna(y.mean(), inplace= True)
# for i in numerical_x:
#     X[i].fillna(X[i].mean(), inplace = True)

# for i in categorical_x:
#     X[i].fillna(X[i].mode().iloc[0], inplace = True)
    
# categoricas = pd.get_dummies(X[categorical_x], drop_first=True)
# X = pd.concat([categoricas, X[numerical_x]], axis = 1)

# %%
X = pd.get_dummies(X, drop_first = True)
y = pd.get_dummies(y, drop_first = False)

# %%
X.head(3)
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0            39.6           18.8              190.0       4600.0
# 1            45.3           13.7              210.0       4300.0
# 2            35.9           16.6              190.0       3050.0
#
#    island_Dream  island_Torgersen  sex_Male
# 0             1                 0         1
# 1             0                 0         0
# 2             0                 1         0

# %%
y.head(3)
# Out:
#    Adelie  Chinstrap  Gentoo
# 0       1          0       0
# 1       0          0       1
# 2       1          0       0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
escalador = StandardScaler()
escalador.fit(X_train)

X_train = escalador.transform(X_train)
X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
X_train.shape
# Out:
# (233, 7)

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=8,activation='relu'))

model.add(Dense(units=4,activation='relu'))


model.add(Dense(units=3,activation='softmax'))


# For a binary classification problem
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
# https://datascience.stackexchange.com/questions/18414/are-there-any-rules-for-choosing-the-size-of-a-mini-batch

model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1
          )
# Out:
# Epoch 1/600
# 8/8 [==============================] - 1s 23ms/step - loss: 1.1916 - accuracy: 0.3991 - val_loss: 1.2305 - val_accuracy: 0.3700
# Epoch 2/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1470 - accuracy: 0.4464 - val_loss: 1.1788 - val_accuracy: 0.4100
# Epoch 3/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1062 - accuracy: 0.5193 - val_loss: 1.1316 - val_accuracy: 0.4300
# Epoch 4/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0707 - accuracy: 0.5794 - val_loss: 1.0918 - val_accuracy: 0.4900
# Epoch 5/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0381 - accuracy: 0.6223 - val_loss: 1.0580 - val_accuracy: 0.5100
# Epoch 6/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0087 - accuracy: 0.6609 - val_loss: 1.0262 - val_accuracy: 0.5400
# Epoch 7/600
# ...

# %% [markdown]
# ## Evaluation

# %%
model.history.history
# Out:
# {'loss': [1.191635012626648,
#   1.1469630002975464,
#   1.106196641921997,
#   1.0707099437713623,
#   1.0381126403808594,
#   1.0086510181427002,
#   0.9797072410583496,
#   0.9520297050476074,
#   0.9253294467926025,
#   0.8985252380371094,
#   0.8727335333824158,
#   0.8466864824295044,
#   0.8212021589279175,
#   0.7953662276268005,
#   0.7699994444847107,
#   0.7451702952384949,
#   0.7209439873695374,
#   0.6978299021720886,
#   0.6750560402870178,
#   0.6527909636497498,
#   0.6304495334625244,
#   0.6088998913764954,
#   0.5866036415100098,
#   0.5653136372566223,
#   0.5427810549736023,
#   0.5196315050125122,
#   0.4957709014415741,
#   0.4714978337287903,
#   0.4469395875930786,
#   0.42151322960853577,
#   0.39668262004852295,
#   0.37297260761260986,
#   0.3509211540222168,
#   0.33093276619911194,
#   0.31176501512527466,
#   0.29427215456962585,
#   0.2771049737930298,
#   0.26149946451187134,
#   0.24640251696109772,
#   0.23174457252025604,
#   0.21887706220149994,
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
# loss = model.history.history['loss']
# sns.lineplot(x=range(len(loss)),y=loss)
# plt.title("Training Loss per Epoch");

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
training_score = model.evaluate(X_train,y_train,verbose=0)
test_score = model.evaluate(X_test,y_test,verbose=0)

# %%
training_score
# Out:
# [0.0009521387983113527, 1.0]

# %%
test_score
# Out:
# [7.039237243589014e-05, 1.0]

# %%
predictions = model.predict(X_test)
predictions = pd.Series(np.argmax(predictions,axis=1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
predictions.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# dtype: object

# %%
y_test_simple = pd.Series(np.argmax(y_test.to_numpy(), axis = 1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
pred_df = pd.DataFrame(y_test_simple, columns = ['Test_Y']).reset_index(drop = True)
pred_df['Model_Predictions'] = predictions

# %%
pred_df.head()
# Out:
#    Test_Y Model_Predictions
# 0  Adelie            Adelie
# 1  Adelie            Adelie
# 2  Adelie            Adelie
# 3  Adelie            Adelie
# 4  Adelie            Adelie

# %%
metrics.accuracy_score(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# 1.0

# %%
metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# array([[56,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0, 30]], dtype=int64)

# %%
cm = metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=y.columns).plot()

# %%
print(metrics.classification_report(pred_df['Test_Y'],pred_df['Model_Predictions']))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        56
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        30
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %% [markdown]
# ## Early Stopping

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=8,activation='relu'))

model.add(Dense(units=4,activation='relu'))


model.add(Dense(units=3,activation='softmax'))


# For a binary classification problem
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop, board]
          )
# Out:
# Epoch 1/600
# 8/8 [==============================] - 1s 43ms/step - loss: 1.1212 - accuracy: 0.3047 - val_loss: 1.0534 - val_accuracy: 0.3000
# Epoch 2/600
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0933 - accuracy: 0.2361 - val_loss: 1.0269 - val_accuracy: 0.2200
# Epoch 3/600
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0670 - accuracy: 0.2103 - val_loss: 1.0020 - val_accuracy: 0.2800
# Epoch 4/600
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0423 - accuracy: 0.2275 - val_loss: 0.9778 - val_accuracy: 0.3500
# Epoch 5/600
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0188 - accuracy: 0.2747 - val_loss: 0.9534 - val_accuracy: 0.4500
# Epoch 6/600
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9961 - accuracy: 0.3219 - val_loss: 0.9281 - val_accuracy: 0.5500
# Epoch 7/600
# ...

# %% [markdown]
# ## Evaluation

# %%
model.history.history
# Out:
# {'loss': [1.1212126016616821,
#   1.0933046340942383,
#   1.0670193433761597,
#   1.0423375368118286,
#   1.0188406705856323,
#   0.996106743812561,
#   0.9738192558288574,
#   0.9511483907699585,
#   0.9288712739944458,
#   0.9074323773384094,
#   0.8858982920646667,
#   0.8630292415618896,
#   0.839779257774353,
#   0.8171422481536865,
#   0.7951859831809998,
#   0.7743569612503052,
#   0.7528183460235596,
#   0.7342911958694458,
#   0.7170310020446777,
#   0.702325165271759,
#   0.6886582970619202,
#   0.676102876663208,
#   0.664315402507782,
#   0.6534541845321655,
#   0.6431640982627869,
#   0.6333889365196228,
#   0.6240399479866028,
#   0.6151524782180786,
#   0.6065155863761902,
#   0.5980178713798523,
#   0.5896049737930298,
#   0.581477701663971,
#   0.573133647441864,
#   0.5650835037231445,
#   0.5569287538528442,
#   0.5486904382705688,
#   0.5402406454086304,
#   0.5316282510757446,
#   0.5230386853218079,
#   0.5143036842346191,
#   0.505541980266571,
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
# loss = model.history.history['loss']
# sns.lineplot(x=range(len(loss)),y=loss)
# plt.title("Training Loss per Epoch");

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
training_score = model.evaluate(X_train,y_train,verbose=0)
test_score = model.evaluate(X_test,y_test,verbose=0)

# %%
training_score
# Out:
# [0.0004970621084794402, 1.0]

# %%
test_score
# Out:
# [6.645190296694636e-05, 1.0]

# %%
predictions = model.predict(X_test)
predictions = pd.Series(np.argmax(predictions,axis=1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
# Out:
# 4/4 [==============================] - 0s 1000us/step

# %%
predictions.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# dtype: object

# %%
y_tes_simplet = pd.Series(np.argmax(y_test.to_numpy(), axis = 1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
pred_df = pd.DataFrame(y_test_simple, columns = ['Test_Y']).reset_index(drop = True)
pred_df['Model_Predictions'] = predictions

# %%
pred_df.head()
# Out:
#    Test_Y Model_Predictions
# 0  Adelie            Adelie
# 1  Adelie            Adelie
# 2  Adelie            Adelie
# 3  Adelie            Adelie
# 4  Adelie            Adelie

# %%
metrics.accuracy_score(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# 1.0

# %%
metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# array([[56,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0, 30]], dtype=int64)

# %%
cm = metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=y.columns).plot()

# %%
print(metrics.classification_report(pred_df['Test_Y'],pred_df['Model_Predictions']))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        56
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        30
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %% [markdown]
# ## Adding in DropOut Layers

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=8,activation='relu'))

model.add(Dense(units=4,activation='relu'))


model.add(Dense(units=3,activation='softmax'))


# For a binary classification problem
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/600
# 8/8 [==============================] - 1s 19ms/step - loss: 1.1105 - accuracy: 0.3133 - val_loss: 1.0994 - val_accuracy: 0.2800
# Epoch 2/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0952 - accuracy: 0.3562 - val_loss: 1.0885 - val_accuracy: 0.3200
# Epoch 3/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0800 - accuracy: 0.4335 - val_loss: 1.0758 - val_accuracy: 0.4400
# Epoch 4/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0626 - accuracy: 0.5279 - val_loss: 1.0600 - val_accuracy: 0.5300
# Epoch 5/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0430 - accuracy: 0.6052 - val_loss: 1.0423 - val_accuracy: 0.5900
# Epoch 6/600
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0203 - accuracy: 0.6524 - val_loss: 1.0228 - val_accuracy: 0.6400
# Epoch 7/600
# ...

# %% [markdown]
# ## Evaluation

# %%
model.history.history
# Out:
# {'loss': [1.1104761362075806,
#   1.0952335596084595,
#   1.080025315284729,
#   1.0626412630081177,
#   1.043039083480835,
#   1.0203416347503662,
#   0.9968760013580322,
#   0.9709087610244751,
#   0.9415735602378845,
#   0.9088034629821777,
#   0.8755890130996704,
#   0.8429424166679382,
#   0.8116647005081177,
#   0.7826074361801147,
#   0.755548357963562,
#   0.7288219928741455,
#   0.7048287987709045,
#   0.6812244057655334,
#   0.6598303318023682,
#   0.6395130157470703,
#   0.6207008361816406,
#   0.6025324463844299,
#   0.585938036441803,
#   0.5700929164886475,
#   0.5549106597900391,
#   0.5408435463905334,
#   0.5276842713356018,
#   0.5151780843734741,
#   0.5034539103507996,
#   0.4924676716327667,
#   0.48179423809051514,
#   0.4717133045196533,
#   0.4620652198791504,
#   0.45268890261650085,
#   0.4436979293823242,
#   0.43472328782081604,
#   0.42601674795150757,
#   0.41736143827438354,
#   0.4085118770599365,
#   0.39954787492752075,
#   0.39052650332450867,
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
# loss = model.history.history['loss']
# sns.lineplot(x=range(len(loss)),y=loss)
# plt.title("Training Loss per Epoch");

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
training_score = model.evaluate(X_train,y_train,verbose=0)
test_score = model.evaluate(X_test,y_test,verbose=0)

# %%
training_score
# Out:
# [0.0005448797019198537, 1.0]

# %%
test_score
# Out:
# [0.00012467056512832642, 1.0]

# %%
predictions = model.predict(X_test)
predictions = pd.Series(np.argmax(predictions,axis=1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
predictions.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# dtype: object

# %%
y_test_simple = pd.Series(np.argmax(y_test.to_numpy(), axis = 1)).replace({0: 'Adelie', 1: 'Chinstrap', 2:'Gentoo'})
pred_df = pd.DataFrame(y_test_simple, columns = ['Test_Y']).reset_index(drop = True)
pred_df['Model_Predictions'] = predictions

# %%
pred_df.head()
# Out:
#    Test_Y Model_Predictions
# 0  Adelie            Adelie
# 1  Adelie            Adelie
# 2  Adelie            Adelie
# 3  Adelie            Adelie
# 4  Adelie            Adelie

# %%
metrics.accuracy_score(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# 1.0

# %%
metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
# Out:
# array([[56,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0, 30]], dtype=int64)

# %%
cm = metrics.confusion_matrix(pred_df['Test_Y'],pred_df['Model_Predictions'])
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=y.columns).plot()

# %%
print(metrics.classification_report(pred_df['Test_Y'],pred_df['Model_Predictions']))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        56
#    Chinstrap       1.00      1.00      1.00        14
#       Gentoo       1.00      1.00      1.00        30
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %% [markdown]
# ## Saving and Loading a Model

# %%
# from tensorflow.keras.models import load_model

# %%
# model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'

# %%
# later_model = load_model('my_model.h5')
