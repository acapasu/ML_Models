# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
# df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['species'], axis = 1)
y = df_pen['species']

# %% [markdown]
# ## Data Pre-processing

# %%
categorical_x = ['island', 'sex']
numerical_x = X.drop(categorical_x, axis = 1).columns

# %%
## If y is categorical:
y.fillna(y.mode(), inplace= True)
##If y is numerical
# y.fillna(y.mean(), inplace= True)
for i in numerical_x:
    X[i].fillna(X[i].mean(), inplace = True)

for i in categorical_x:
    X[i].fillna(X[i].mode().iloc[0], inplace = True)
    
categoricas = pd.get_dummies(X[categorical_x], drop_first=True)
X = pd.concat([categoricas, X[numerical_x]], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
# escalador = StandardScaler()
# escalador.fit(X_train)

# X_train = escalador.transform(X_train)
# X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = dt_model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
y_pred = dt_model.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9711538461538461

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[38,  1,  0],
#        [ 1, 22,  0],
#        [ 1,  0, 41]], dtype=int64)

# %%
metrics.plot_confusion_matrix(dt_model, X_test,y_test)

# %%
metrics.plot_confusion_matrix(dt_model, X_test,y_test,normalize='true')

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.97      0.96        39
#    Chinstrap       0.96      0.96      0.96        23
#       Gentoo       1.00      0.98      0.99        42
#
#     accuracy                           0.97       104
#    macro avg       0.97      0.97      0.97       104
# weighted avg       0.97      0.97      0.97       104

# %%
dt_model.feature_importances_
# Out:
# array([0.03901682, 0.01662879, 0.        , 0.34394972, 0.04736584,
#        0.55303884, 0.        ])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=dt_model.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# flipper_length_mm            0.553039
# bill_length_mm               0.343950
# bill_depth_mm                0.047366
# island_Dream                 0.039017
# island_Torgersen             0.016629
# sex_Male                     0.000000
# body_mass_g                  0.000000

# %% [markdown]
# ## Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(dt_model, feature_names= X.columns, filled = True);

# %% [markdown]
# ## Grid Search

# %%
dt_model = DecisionTreeClassifier()

# %%
parametros = {'criterion':['gini', 'entropy'], 'max_depth': [3,4,5,6,7]}

# %%
grid_model = GridSearchCV(dt_model,param_grid= parametros, cv = 5, scoring='accuracy', n_jobs=-1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7]},
#              scoring='accuracy')

# %%
grid_model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 6}

# %%
y_pred = grid_model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9807692307692307

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[38,  1,  0],
#        [ 0, 22,  1],
#        [ 0,  0, 42]], dtype=int64)

# %%
metrics.plot_confusion_matrix(grid_model, X_test,y_test)

# %%
metrics.plot_confusion_matrix(grid_model, X_test,y_test,normalize='true')

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      0.97      0.99        39
#    Chinstrap       0.96      0.96      0.96        23
#       Gentoo       0.98      1.00      0.99        42
#
#     accuracy                           0.98       104
#    macro avg       0.98      0.98      0.98       104
# weighted avg       0.98      0.98      0.98       104

# %%
grid_model.best_estimator_.feature_importances_
# Out:
# array([0.03901682, 0.00665152, 0.        , 0.33397245, 0.05235447,
#        0.55802747, 0.00997727])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=grid_model.best_estimator_.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# flipper_length_mm            0.558027
# bill_length_mm               0.333972
# bill_depth_mm                0.052354
# island_Dream                 0.039017
# body_mass_g                  0.009977
# island_Torgersen             0.006652
# sex_Male                     0.000000

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(grid_model.best_estimator_, feature_names= X.columns, filled = True);
