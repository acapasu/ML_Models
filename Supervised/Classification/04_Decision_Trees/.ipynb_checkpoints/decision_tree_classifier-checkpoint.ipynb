# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
# df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['species'], axis = 1)
y = df_pen['species']

# %% [markdown]
# ## Data Pre-processing

# %%
categorical_x = ['island', 'sex']
numerical_x = X.drop(categorical_x, axis = 1).columns

# %%
## If y is categorical:
y.fillna(y.mode(), inplace= True)
##If y is numerical
# y.fillna(y.mean(), inplace= True)
for i in numerical_x:
    X[i].fillna(X[i].mean(), inplace = True)

for i in categorical_x:
    X[i].fillna(X[i].mode().iloc[0], inplace = True)
    
categoricas = pd.get_dummies(X[categorical_x], drop_first=True)
X = pd.concat([categoricas, X[numerical_x]], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
# escalador = StandardScaler()
# escalador.fit(X_train)

# X_train = escalador.transform(X_train)
# X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = dt_model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
y_pred = dt_model.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9326923076923077

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[53,  0,  1],
#        [ 5, 17,  0],
#        [ 1,  0, 27]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=dt_model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.90      0.98      0.94        54
#    Chinstrap       1.00      0.77      0.87        22
#       Gentoo       0.96      0.96      0.96        28
#
#     accuracy                           0.93       104
#    macro avg       0.95      0.91      0.92       104
# weighted avg       0.94      0.93      0.93       104

# %%
dt_model.feature_importances_
# Out:
# array([0.04764933, 0.        , 0.        , 0.34780672, 0.00148771,
#        0.60305623, 0.        ])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=dt_model.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# flipper_length_mm            0.603056
# bill_length_mm               0.347807
# island_Dream                 0.047649
# bill_depth_mm                0.001488
# island_Torgersen             0.000000
# sex_Male                     0.000000
# body_mass_g                  0.000000

# %% [markdown]
# ## Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(dt_model, feature_names= X.columns, filled = True);

# %% [markdown]
# ## Grid Search

# %%
dt_model = DecisionTreeClassifier()

# %%
parametros = {'criterion':['gini', 'entropy'], 'max_depth': [3,4,5,6,7]}

# %%
grid_model = GridSearchCV(dt_model,param_grid= parametros, cv = 5, scoring='accuracy', n_jobs=-1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7]},
#              scoring='accuracy')

# %%
grid_model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5}

# %%
y_pred = grid_model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9711538461538461

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[53,  0,  1],
#        [ 1, 21,  0],
#        [ 1,  0, 27]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=grid_model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      0.98      0.97        54
#    Chinstrap       1.00      0.95      0.98        22
#       Gentoo       0.96      0.96      0.96        28
#
#     accuracy                           0.97       104
#    macro avg       0.98      0.97      0.97       104
# weighted avg       0.97      0.97      0.97       104

# %%
grid_model.best_estimator_.feature_importances_
# Out:
# array([0.04764933, 0.        , 0.        , 0.35435265, 0.00148771,
#        0.5965103 , 0.        ])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=grid_model.best_estimator_.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# flipper_length_mm            0.596510
# bill_length_mm               0.354353
# island_Dream                 0.047649
# bill_depth_mm                0.001488
# island_Torgersen             0.000000
# sex_Male                     0.000000
# body_mass_g                  0.000000

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(grid_model.best_estimator_, feature_names= X.columns, filled = True);
