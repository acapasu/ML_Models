# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['species'], axis = 1)
y = df_pen['species']

# %% [markdown]
# ## Data Pre-processing

# %%
categorical_x = ['island', 'sex']
numerical_x = X.drop(categorical_x, axis = 1).columns

# %%
# ## If y is categorical:
# y.fillna(y.mode(), inplace= True)
# ##If y is numerical
# # y.fillna(y.mean(), inplace= True)
# for i in numerical_x:
#     X[i].fillna(X[i].mean(), inplace = True)

# for i in categorical_x:
#     X[i].fillna(X[i].mode().iloc[0], inplace = True)
    
categoricas = pd.get_dummies(X[categorical_x], drop_first=True)
X = pd.concat([categoricas, X[numerical_x]], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=101)

# %%
# escalador = StandardScaler()
# escalador.fit(X_train)

# X_train = escalador.transform(X_train)
# X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
base_pred = rf_model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
y_pred = rf_model.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[20,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 17]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=rf_model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        20
#    Chinstrap       1.00      1.00      1.00        13
#       Gentoo       1.00      1.00      1.00        17
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %%
rf_model.feature_importances_
# Out:
# array([0.10649485, 0.02129857, 0.01017447, 0.32922989, 0.1219099 ,
#        0.2759908 , 0.13490152])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=rf_model.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# bill_length_mm               0.329230
# flipper_length_mm            0.275991
# body_mass_g                  0.134902
# bill_depth_mm                0.121910
# island_Dream                 0.106495
# island_Torgersen             0.021299
# sex_Male                     0.010174

# %% [markdown]
# ## Grid Search

# %%
rf_model = RandomForestClassifier()

# %%
n_estimators=[64,100,128,200]
max_features= [2,3,4]
bootstrap = [True,False]

parametros = {'n_estimators':n_estimators,
              'max_features':max_features,
              'bootstrap':bootstrap,}

# %%
grid_model = GridSearchCV(rf_model,param_grid= parametros, cv = 5, scoring='accuracy', n_jobs=-1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [64, 100, 128, 200]},
#              scoring='accuracy')

# %%
grid_model.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 64}

# %%
y_pred = grid_model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.98

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[19,  1,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 17]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=grid_model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      0.95      0.97        20
#    Chinstrap       0.93      1.00      0.96        13
#       Gentoo       1.00      1.00      1.00        17
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %%
grid_model.best_estimator_.feature_importances_
# Out:
# array([0.10311994, 0.02228907, 0.00870845, 0.33962871, 0.16068864,
#        0.28465648, 0.08090871])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=grid_model.best_estimator_.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# bill_length_mm               0.339629
# flipper_length_mm            0.284656
# bill_depth_mm                0.160689
# island_Dream                 0.103120
# body_mass_g                  0.080909
# island_Torgersen             0.022289
# sex_Male                     0.008708

# %%
plt.figure(figsize=(14,6),dpi=200)
sns.barplot(data = df_feature_importance,x=df_feature_importance.index,y='Feature Importance')

plt.xticks(rotation=90);

# %% [markdown]
# ## Elbow

# %%
errors = []
misclassifications = []

for n in range(1,64):
    rfc = RandomForestClassifier( n_estimators=n,bootstrap=True,max_features= 2)
    rfc.fit(X_train,y_train)
    preds = rfc.predict(X_test)
    err = 1 - metrics.accuracy_score(preds,y_test)
    n_missed = np.sum(preds != y_test) # watch the video to understand this line!!
    errors.append(err)
    misclassifications.append(n_missed)

# %%
plt.plot(range(1,64),errors)

# %%
plt.plot(range(1,64),misclassifications)
