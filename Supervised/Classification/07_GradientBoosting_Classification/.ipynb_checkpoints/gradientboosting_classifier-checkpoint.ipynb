# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['species'], axis = 1)
y = df_pen['species']

# %% [markdown]
# ## Data Pre-processing

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=101)

# %%
escalador = StandardScaler()
escalador.fit(X_train)

X_train = escalador.transform(X_train)
X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
model = GradientBoostingClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
base_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.94

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  1,  0],
#        [ 2,  8,  0],
#        [ 0,  0, 23]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.89      0.94      0.91        17
#    Chinstrap       0.89      0.80      0.84        10
#       Gentoo       1.00      1.00      1.00        23
#
#     accuracy                           0.94        50
#    macro avg       0.93      0.91      0.92        50
# weighted avg       0.94      0.94      0.94        50

# %%
model.feature_importances_
# Out:
# array([4.74685760e-01, 5.40197477e-02, 3.23073108e-01, 1.48647032e-03,
#        1.22762585e-01, 2.39722435e-02, 8.60409585e-08])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=model.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# bill_length_mm           4.746858e-01
# flipper_length_mm        3.230731e-01
# island_Dream             1.227626e-01
# bill_depth_mm            5.401975e-02
# island_Torgersen         2.397224e-02
# body_mass_g              1.486470e-03
# sex_Male                 8.604096e-08

# %%
plt.figure(figsize=(14,6),dpi=200)
sns.barplot(data = df_feature_importance,x=df_feature_importance.index,y='Feature Importance')

plt.xticks(rotation=90);

# %% [markdown]
# ## Grid Search

# %%
model = GradientBoostingClassifier()

# %%
parametros = {"n_estimators":[1,5,10,20,40,100],'max_depth':[3,4,5,6]}

# %%
grid_model = GridSearchCV(model,param_grid= parametros, cv = 5, scoring='accuracy', n_jobs=-1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5, 6],
#                          'n_estimators': [1, 5, 10, 20, 40, 100]},
#              scoring='accuracy')

# %%
grid_model.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 5}

# %%
y_pred = grid_model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.96

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[17,  0,  0],
#        [ 2,  8,  0],
#        [ 0,  0, 23]], dtype=int64)

# %%
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=grid_model.classes_).plot()

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.89      1.00      0.94        17
#    Chinstrap       1.00      0.80      0.89        10
#       Gentoo       1.00      1.00      1.00        23
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.93      0.94        50
# weighted avg       0.96      0.96      0.96        50

# %%
grid_model.best_estimator_.feature_importances_
# Out:
# array([0.46852176, 0.04590033, 0.32109884, 0.00312271, 0.11801395,
#        0.0301745 , 0.01316792])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=grid_model.best_estimator_.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# bill_length_mm               0.468522
# flipper_length_mm            0.321099
# island_Dream                 0.118014
# bill_depth_mm                0.045900
# island_Torgersen             0.030175
# sex_Male                     0.013168
# body_mass_g                  0.003123

# %%
plt.figure(figsize=(14,6),dpi=200)
sns.barplot(data = df_feature_importance,x=df_feature_importance.index,y='Feature Importance')

plt.xticks(rotation=90);

# %% [markdown]
# ## Elbow

# %%
errors = []
misclassifications = []

for n in range(1,64):
    rfc = GradientBoostingClassifier( n_estimators=n)
    rfc.fit(X_train,y_train)
    preds = rfc.predict(X_test)
    err = 1 - metrics.accuracy_score(preds,y_test)
    n_missed = np.sum(preds != y_test)
    errors.append(err)
    misclassifications.append(n_missed)

# %%
plt.plot(range(1,64),errors)

# %%
plt.plot(range(1,64),misclassifications)
