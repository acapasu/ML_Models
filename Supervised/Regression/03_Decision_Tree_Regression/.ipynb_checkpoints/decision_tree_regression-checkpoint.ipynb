# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## Import Dataset

# %%
df_pen = sns.load_dataset('penguins')

# %%
# df_pen = df_pen.dropna()

# %%
df_pen = df_pen.sample(frac=1).reset_index(drop=True)

# %%
X = df_pen.drop(['body_mass_g'], axis = 1)
y = df_pen['body_mass_g']

# %% [markdown]
# ## Data Pre-processing

# %%
categorical_x = ['species', 'island', 'sex']
numerical_x = X.drop(categorical_x, axis = 1).columns

# %%
## If y is categorical:
# y.fillna(y.mode(), inplace= True)
##If y is numerical
y.fillna(y.mean(), inplace= True)
for i in numerical_x:
    X[i].fillna(X[i].mean(), inplace = True)

for i in categorical_x:
    X[i].fillna(X[i].mode().iloc[0], inplace = True)
    
categoricas = pd.get_dummies(X[categorical_x], drop_first=True)
X = pd.concat([categoricas, X[numerical_x]], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
# escalador = StandardScaler()
# escalador.fit(X_train)

# X_train = escalador.transform(X_train)
# X_test = escalador.transform(X_test)

# %% [markdown]
# ## Model implementation

# %%
dt_model = DecisionTreeRegressor()

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
base_preds = dt_model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
print(f'Mean Absolute Error: {metrics.mean_absolute_error(y_test, base_preds)}')
print(f'Mean Squared Error: {metrics.mean_squared_error(y_test, base_preds)}')
print(f'Root Mean Squared Error: {np.sqrt(metrics.mean_squared_error(y_test, base_preds))}')
# Out:
# Mean Absolute Error: 349.02159244264504
# Mean Squared Error: 182296.33526292114
# Root Mean Squared Error: 426.9617491800889

# %%
dt_model.feature_importances_
# Out:
# array([9.58810222e-03, 6.92965421e-01, 3.38149266e-04, 3.10984012e-03,
#        1.49049856e-01, 5.91385423e-02, 4.39763291e-02, 4.18337597e-02])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=dt_model.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# species_Gentoo               0.692965
# sex_Male                     0.149050
# bill_length_mm               0.059139
# bill_depth_mm                0.043976
# flipper_length_mm            0.041834
# species_Chinstrap            0.009588
# island_Torgersen             0.003110
# island_Dream                 0.000338

# %% [markdown]
# ## Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(dt_model, feature_names= X.columns, filled = True);

# %% [markdown]
# ## Grid Search

# %%
dt_model = DecisionTreeRegressor()

# %%
parametros = {'criterion':['mse', 'mae'], 'max_depth': [3,4,5,10,15,20]}

# %%
grid_model = GridSearchCV(dt_model,param_grid= parametros, cv = 5, scoring='accuracy', n_jobs=-1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_depth': [3, 4, 5, 10, 15, 20]},
#              scoring='accuracy')

# %%
grid_model.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 3}

# %%
y_pred = grid_model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
print(f'Mean Absolute Error: {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'Mean Squared Error: {metrics.mean_squared_error(y_test, y_pred)}')
print(f'Root Mean Squared Error: {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
# Out:
# Mean Absolute Error: 268.5983394389989
# Mean Squared Error: 119781.51182301252
# Root Mean Squared Error: 346.0946573164812

# %%
grid_model.best_estimator_.feature_importances_
# Out:
# array([0.        , 0.79243669, 0.        , 0.        , 0.17044512,
#        0.00907461, 0.00823827, 0.01980531])

# %%
df_feature_importance = pd.DataFrame(index=X.columns,data=grid_model.best_estimator_.feature_importances_,columns=['Feature Importance'])
df_feature_importance = df_feature_importance.sort_values('Feature Importance', ascending = False)
df_feature_importance
# Out:
#                    Feature Importance
# species_Gentoo               0.792437
# sex_Male                     0.170445
# flipper_length_mm            0.019805
# bill_length_mm               0.009075
# bill_depth_mm                0.008238
# species_Chinstrap            0.000000
# island_Dream                 0.000000
# island_Torgersen             0.000000

# %%
plt.figure(figsize=(12,8), dpi = 200)
plot_tree(grid_model.best_estimator_, feature_names= X.columns, filled = True);
