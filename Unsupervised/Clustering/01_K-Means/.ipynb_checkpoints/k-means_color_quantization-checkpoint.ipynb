# %% [markdown]
# # K Means Color Quantization

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import os

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %% [markdown]
# ## Import Image

# %%
image_as_array = mpimg.imread(os.getcwd()+'/Data/background.jpg')

# %%
image_as_array.shape
# Out:
# (720, 1280, 3)

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(image_as_array)

# %% [markdown]
# ### Convert from 3d to 2d
#
# Kmeans is designed to train on 2D data (data rows and feature columns), so we can reshape the above strip by using (h,w,c) ---> (h * w,c)

# %%
(h,w,c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
model.cluster_centers_
# Out:
# array([[140.69153226, 149.66153951, 125.22351848],
#        [ 36.07892631,  41.76463468,  30.15333402],
#        [ 67.29329893,  84.26685428,  64.23348098],
#        [ 17.72503744,  23.54457342,  17.5444906 ],
#        [ 52.00433855,  59.86992963,  42.59265512],
#        [ 98.46674626, 123.674449  , 103.63767789]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[141, 150, 125],
#        [ 36,  42,  30],
#        [ 67,  84,  64],
#        [ 18,  24,  18],
#        [ 52,  60,  43],
#        [ 98, 124, 104]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18],
#         ...,
#         [18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18]],
#
#        [[18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18],
#         ...,
#         [18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18]],
#
#        [[18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18],
#         ...,
#         [18, 24, 18],
#         [18, 24, 18],
#         [18, 24, 18]],
#
#        ...,
#
#        [[36, 42, 30],
#         [36, 42, 30],
#         [36, 42, 30],
#         ...,
#         [52, 60, 43],
#         [52, 60, 43],
#         [52, 60, 43]],
#
#        [[36, 42, 30],
#         [36, 42, 30],
#         [36, 42, 30],
#         ...,
#         [52, 60, 43],
#         [52, 60, 43],
#         [52, 60, 43]],
#
#        [[36, 42, 30],
#         [36, 42, 30],
#         [36, 42, 30],
#         ...,
#         [52, 60, 43],
#         [52, 60, 43],
#         [36, 42, 30]]])

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(quantized_image)
